# %%
! python --version
# Out:
# Python 3.12.13

# %%
print("Hello Kohin")
print(100)
# Out:
# Hello Kohin
# 100

# %%
print(type("Hello Kohin"))
print(type(100))
print(type(100.098))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
msg = 'hello this is kohin'
n = 123
pi = 3.1416
print(msg,n,pi)
# Out:
# hello this is kohin 123 3.1416

# %%
x,y,z = 14,  15.5, 'kohin'
print(x)
print(y)
print(z)
# Out:
# 14
# 15.5
# kohin

# %%
a = b = c = 'kohin'
print(a)
print(b)
print(c)
# Out:
# kohin
# kohin
# kohin

# %%
type('kohin')
# Out:
# str

# %%
num1 = 123; num2 = 1.23

num3 = num1 + num2

print("datatype of num1:",type(num1))
print("datatype of num2:",type(num2))

print("Value of num3:",num3)
print("datatype of num3:",type(num3))
# Out:
# datatype of num1: <class 'int'>
# datatype of num2: <class 'float'>
# Value of num3: 124.23
# datatype of num3: <class 'float'>

# %%
num_str = '1234'
num_int = 1

num_str = int(num_str)

print(num_str+num_int)
# Out:
# 1235

# %%
a = 7; b = 3

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 10
# 4
# 21
# 2.3333333333333335
# 2
# 1
# 343

# %%
x = 5
x+1
# Out:
# 6

# %%
a = 10; b = 20
print(a+b)

#string
a = '10'
b = '20'
print(a+b)
# Out:
# 30
# 1020

# %%
print(a+ ' ' +b)
# Out:
# 10 20

# %%
#a = input('Plz Give e value : ')
a = 5
print(a)
print(type(a))
# Out:
# 5
# <class 'int'>

# %%
#a = int(input('Plz Give e value : '))
a = 10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
m = 10; n = 20
print('The value of m is {} and value of n is {}'.format(m,n))
# Out:
# The value of m is 10 and value of n is 20

# %%
print('The value of x is {x} and value of y is {y}'.format(x = 2,y = 3))
# Out:
# The value of x is 2 and value of y is 3

# %%
m = 10; n = 20
print(f'The value of m is {m} and value of n is {n}')
# Out:
# The value of m is 10 and value of n is 20

# %%
w = 3; y = 7; z = 5
print(f'{w} + {y} + {z} = ',w+y+z)
# Out:
# 3 + 7 + 5 =  15

# %%
x = 65
y = 100.56789
print("The value of x is %c" %x)
print("The value of x is %f" %y)
print("The value of x is %.2f" %y)
print("The value of x is %f" %x)
print("The value of x is %.0f" %x)
# Out:
# The value of x is A
# The value of x is 100.567890
# The value of x is 100.57
# The value of x is 65.000000
# The value of x is 65

# %%
a = 66.787964
print(round(a,3))
# Out:
# 66.788

# %%
from math import sqrt,pi
print(sqrt(64))
# Out:
# 8.0

# %%
#var = input("Enter your name : ")
var = "Kohin"
print(f"Hello {var}")
print("Hello "+var)
# Out:
# Hello Kohin
# Hello Kohin

# %%
#h = float(input("Enter Hours : "))
#r = float(input("Enter Rate : "))
h = 2
r = 3
print(f"Pay : {h*r}")
# Out:
# Pay : 6

# %%
#c= float(input('Enter Celsius Value : '))
c = 35
f =  (c* 9/5) + 32
print("Fahrenheit : ",f)
# Out:
# Fahrenheit :  95.0

# %%
from math import sqrt
#l = float(input("Rectangle length : "))
#w = float(input("Rectangle width : "))

l = 20
r = 10
print("Area = ",l*w)
print("Diagonal = ",round(sqrt(l**2+w**2),2))
print("Perimeter = ",2*(l+w))
# Out:
# Area =  400.0
# Diagonal =  28.28
# Perimeter =  80.0

# %%
#h = float(input("Enter Height : "))
#a = float(input("Enter Base 1 : "))
#b = float(input("Enter Base 2 : "))

h = 20
a = 2
b = 4
print("Area = ",((a+b)/2)*h)
# Out:
# Area =  60.0

# %%
from math import pi
#h = float(input("Enter Height : "))
#r = float(input("Enter Radius : "))

h = 10
r = 2

print("Surface Volume = ",round(pi*r*r*h,2))
print("Total Surface Area = ",round((2*pi*r*(r+h)),2))
# Out:
# Surface Volume =  125.66
# Total Surface Area =  150.8

# %%
from math import pi
#r = float(input("Enter Radius : "))
#a = float(input("Enter Angle : "))

r = 54
a = 45
print("Arc Length = ",round((a/360)*2*pi*r,2))
print("Sector Area = ",round((a/360)*pi*r*r,2))
# Out:
# Arc Length =  42.41
# Sector Area =  1145.11
